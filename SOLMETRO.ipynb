# %%
import numpy as np
import random

# %%
class Entrance:
  def __init__(self, initialPeople = 100):
    self.quantity = initialPeople

  def enterEntrance(self, amount, source):
    self.quantity += amount
    print(f"{amount} people entered the entrance from {source}")

  def leaveEntrance(self, amount, destination):
    self.quantity -= amount
    print(f"{amount} people left entrance to {destination}")

  def externalArrival(self):
    arrivals = random.randint(5, 20)
    self.quantity += arrivals
    print(f"{arrivals} new people arrived at Entrance from outside")

  def externalDeparture(self):
    if self.quantity > 0:
      departures = min(random.randint(5, 20), self.quantity)  # Cannot remove more than available
      self.quantity -= departures
      print(f"{departures} people left Entrance to outside")

  def reportEntrance(self):
    print(f"currently {self.quantity} in Entrance")

# %%
class Metro:
  def __init__(self, initialPeople = 100):
    self.quantity = initialPeople

  def enterMetro(self, amount, source):
    self.quantity += amount
    print(f"{amount} people entered the Metro from {source}")

  def leaveMetro(self, amount, destination):
    self.quantity -= amount
    print(f"{amount} people left Metro to {destination}")

  def externalArrival(self):
    arrivals = random.randint(5, 20)
    self.quantity += arrivals
    print(f"{arrivals} new people arrived at Metro from outside")

  def externalDeparture(self):
    if self.quantity > 0:
      departures = min(random.randint(5, 20), self.quantity)  # Cannot remove more than available
      self.quantity -= departures
      print(f"{departures} people left Metro to outside")

  def reportMetro(self):
    print(f"currently {self.quantity} in Metro")

# %%
class Cercanias:
  def __init__(self, initialPeople = 100):
    self.quantity = initialPeople

  def enterCercanias(self, amount, source):
    self.quantity += amount
    print(f"{amount} people entered the Cercanias from {source}")

  def leaveCercanias(self, amount, destination):
    self.quantity -= amount
    print(f"{amount} people left Cercanias to {destination}")

  def externalArrival(self):
    arrivals = random.randint(5, 20)
    self.quantity += arrivals
    print(f"{arrivals} new people arrived at Cercanias from outside")

  def externalDeparture(self):
    if self.quantity > 0:
      departures = min(random.randint(5, 20), self.quantity)  # Cannot remove more than available
      self.quantity -= departures
      print(f"{departures} people left Cercanias to outside")

  def reportCercanias(self):
    print(f"currently {self.quantity} in Cercanias")

# %%
import random
import numpy as np  # for using poisson if needed

class PeopleGenerator:
  def __init__(self, arrival_rate=10):
    self.arrival_rate = arrival_rate  # Expected average arrivals per cycle

  def generate(self):
    # You could also use Poisson for more realistic modeling
    return random.randint(int(0.5 * self.arrival_rate), int(1.5 * self.arrival_rate))

# %%
class PeopleSink:
  def __init__(self, departure_rate=10):
    self.departure_rate = departure_rate  # Expected average departures per cycle

  def drain(self, current_population):
    # Ensure we don’t remove more than available
    return min(random.randint(int(0.5 * self.departure_rate), int(1.5 * self.departure_rate)), current_population)

# %%
import matplotlib.pyplot as plt

# Add this before starting the simulation
metro_history = []
entrance_history = []
cercanias_history = []

class peopleFlowSimulation:
  def __init__(self, metro, cercanias, entrance,
               metro_gen=None, cercanias_gen=None, entrance_gen=None,
               metro_sink=None, cercanias_sink=None, entrance_sink=None,
               cycles=10):

    self.metro = metro
    self.cercanias = cercanias
    self.entrance = entrance
    self.cycles = cycles

    self.metro_gen = metro_gen or PeopleGenerator(15)
    self.cercanias_gen = cercanias_gen or PeopleGenerator(15)
    self.entrance_gen = entrance_gen or PeopleGenerator(15)

    self.metro_sink = metro_sink or PeopleSink(10)
    self.cercanias_sink = cercanias_sink or PeopleSink(10)
    self.entrance_sink = entrance_sink or PeopleSink(10)

    # Add tracking lists
    self.metro_history = []
    self.cercanias_history = []
    self.entrance_history = []

  def flow(self):

    for i in range(self.cycles):

      print(f"\n ========== Simulation Cycle {i} ========== \n")

      #Movements from outside the system in
      print("************************************************")
      metro_arrivals = self.metro_gen.generate()
      entrance_arrivals = self.entrance_gen.generate()
      cercanias_arrivals = self.cercanias_gen.generate()

      self.metro.enterMetro(metro_arrivals, "Outside")
      self.entrance.enterEntrance(entrance_arrivals, "Outside")
      self.cercanias.enterCercanias(cercanias_arrivals, "Outside")
      print("************************************************")

      #probability definitions (same as before)...

      metroToMetro = int(self.metro.quantity * 0.45)
      metroToCercanias = int(self.metro.quantity * 0.25)
      metroToEntrance = int(self.metro.quantity * 0.30)

      entranceToEntrance = int(self.entrance.quantity * 0.03)
      entranceToMetro = int(self.entrance.quantity * 0.776)
      entranceToCercanias = int(self.entrance.quantity * 0.194)

      cercaniasToCercanias = int(self.cercanias.quantity * 0.02)
      cercaniasToMetro = int(self.cercanias.quantity * 0.588)
      cercaniasToEntrance = int(self.cercanias.quantity * 0.392)

      # Movement logic (same as your current implementation)...

      if self.metro.quantity >= metroToMetro:
        print(f"{metroToMetro} people stayed in Metro")
      if self.metro.quantity >= metroToCercanias:
        self.metro.leaveMetro(metroToCercanias, "Cercanias")
        self.cercanias.enterCercanias(metroToCercanias, "Metro")
      if self.metro.quantity >= metroToEntrance:
        self.metro.leaveMetro(metroToEntrance, "Entrance")
        self.entrance.enterEntrance(metroToEntrance, "Metro")

      if self.entrance.quantity >= entranceToEntrance:
        print(f"{entranceToEntrance} people stayed in Entrance")
      if self.entrance.quantity >= entranceToMetro:
        self.entrance.leaveEntrance(entranceToMetro, "Metro")
        self.metro.enterMetro(entranceToMetro, "Entrance")
      if self.entrance.quantity >= entranceToCercanias:
        self.entrance.leaveEntrance(entranceToCercanias, "Cercanias")
        self.cercanias.enterCercanias(entranceToCercanias, "Entrance")

      if self.cercanias.quantity >= cercaniasToCercanias:
        print(f"{cercaniasToCercanias} people stayed in Cercanias")
      if self.cercanias.quantity >= cercaniasToMetro:
        self.cercanias.leaveCercanias(cercaniasToMetro, "Metro")
        self.metro.enterMetro(cercaniasToMetro, "Cercanias")
      if self.cercanias.quantity >= cercaniasToEntrance:
        self.cercanias.leaveCercanias(cercaniasToEntrance, "Entrance")
        self.entrance.enterEntrance(cercaniasToEntrance, "Cercanias")

      # External departures
      print("************************************************")
      metro_departures = self.metro_sink.drain(self.metro.quantity)
      entrance_departures = self.entrance_sink.drain(self.entrance.quantity)
      cercanias_departures = self.cercanias_sink.drain(self.cercanias.quantity)

      self.metro.leaveMetro(metro_departures, "Outside")
      self.entrance.leaveEntrance(entrance_departures, "Outside")
      self.cercanias.leaveCercanias(cercanias_departures, "Outside")
      print("************************************************")

      # Save populations for plotting
      self.metro_history.append(self.metro.quantity)
      self.cercanias_history.append(self.cercanias.quantity)
      self.entrance_history.append(self.entrance.quantity)

      # Report
      print("===========================================")
      self.metro.reportMetro()
      self.cercanias.reportCercanias()
      self.entrance.reportEntrance()
      print("===========================================")

  def plot_results(self):
    plt.figure(figsize=(12, 6))
    plt.plot(self.metro_history, label="Metro", color='blue')
    plt.plot(self.cercanias_history, label="Cercanias", color='green')
    plt.plot(self.entrance_history, label="Entrance", color='orange')
    plt.title("Population at Sol Station Over Time")
    plt.xlabel("Simulation Cycle")
    plt.ylabel("Number of People")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
metro1 = Metro(100)
entrance1 = Entrance(100)
cercanias1 = Cercanias(100)

metro_gen = PeopleGenerator(arrival_rate=20)
entrance_gen = PeopleGenerator(arrival_rate=10)
cercanias_gen = PeopleGenerator(arrival_rate=15)

metro_sink = PeopleSink(departure_rate=12)
entrance_sink = PeopleSink(departure_rate=8)
cercanias_sink = PeopleSink(departure_rate=10)

simulation1 = peopleFlowSimulation(
    metro1, cercanias1, entrance1,
    metro_gen, cercanias_gen, entrance_gen,
    metro_sink, cercanias_sink, entrance_sink,
    cycles=100
)

simulation1.flow()
simulation1.plot_results()
# Out:
#  ========== Simulation Cycle 0 ==========
#
# ************************************************
# 18 people entered the Metro from Outside
# 6 people entered the entrance from Outside
# 13 people entered the Cercanias from Outside
# ************************************************
# 53 people stayed in Metro
# 29 people left Metro to Cercanias
# 29 people entered the Cercanias from Metro
# 35 people left Metro to Entrance
# 35 people entered the entrance from Metro
# 3 people stayed in Entrance
# 82 people left entrance to Metro
# 82 people entered the Metro from Entrance
# 20 people left entrance to Cercanias
# 20 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 66 people left Cercanias to Metro
# 66 people entered the Metro from Cercanias
# 44 people left Cercanias to Entrance
# 44 people entered the entrance from Cercanias
# ************************************************
# 14 people left Metro to Outside
# 11 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 188 in Metro
# currently 38 in Cercanias
# currently 72 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 1 ==========
#
# ************************************************
# 20 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 15 people entered the Cercanias from Outside
# ************************************************
# 93 people stayed in Metro
# 52 people left Metro to Cercanias
# 52 people entered the Cercanias from Metro
# 62 people left Metro to Entrance
# 62 people entered the entrance from Metro
# 2 people stayed in Entrance
# 66 people left entrance to Metro
# 66 people entered the Metro from Entrance
# 16 people left entrance to Cercanias
# 16 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 31 people left Cercanias to Metro
# 31 people entered the Metro from Cercanias
# 20 people left Cercanias to Entrance
# 20 people entered the entrance from Cercanias
# ************************************************
# 15 people left Metro to Outside
# 10 people left entrance to Outside
# 13 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 176 in Metro
# currently 57 in Cercanias
# currently 76 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 2 ==========
#
# ************************************************
# 29 people entered the Metro from Outside
# 5 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 92 people stayed in Metro
# 51 people left Metro to Cercanias
# 51 people entered the Cercanias from Metro
# 61 people left Metro to Entrance
# 61 people entered the entrance from Metro
# 2 people stayed in Entrance
# 62 people left entrance to Metro
# 62 people entered the Metro from Entrance
# 15 people left entrance to Cercanias
# 15 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 41 people left Cercanias to Metro
# 41 people entered the Metro from Cercanias
# 27 people left Cercanias to Entrance
# 27 people entered the entrance from Cercanias
# ************************************************
# 10 people left Metro to Outside
# 8 people left entrance to Outside
# 13 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 186 in Metro
# currently 56 in Cercanias
# currently 84 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 3 ==========
#
# ************************************************
# 24 people entered the Metro from Outside
# 11 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 94 people stayed in Metro
# 52 people left Metro to Cercanias
# 52 people entered the Cercanias from Metro
# 63 people left Metro to Entrance
# 63 people entered the entrance from Metro
# 2 people stayed in Entrance
# 73 people left entrance to Metro
# 73 people entered the Metro from Entrance
# 18 people left entrance to Cercanias
# 18 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 41 people left Cercanias to Metro
# 41 people entered the Metro from Cercanias
# 27 people left Cercanias to Entrance
# 27 people entered the entrance from Cercanias
# ************************************************
# 11 people left Metro to Outside
# 8 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 198 in Metro
# currently 67 in Cercanias
# currently 86 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 4 ==========
#
# ************************************************
# 15 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 18 people entered the Cercanias from Outside
# ************************************************
# 95 people stayed in Metro
# 53 people left Metro to Cercanias
# 53 people entered the Cercanias from Metro
# 63 people left Metro to Entrance
# 63 people entered the entrance from Metro
# 2 people stayed in Entrance
# 72 people left entrance to Metro
# 72 people entered the Metro from Entrance
# 18 people left entrance to Cercanias
# 18 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 49 people left Cercanias to Metro
# 49 people entered the Metro from Cercanias
# 33 people left Cercanias to Entrance
# 33 people entered the entrance from Cercanias
# ************************************************
# 9 people left Metro to Outside
# 4 people left entrance to Outside
# 10 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 209 in Metro
# currently 64 in Cercanias
# currently 96 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 5 ==========
#
# ************************************************
# 17 people entered the Metro from Outside
# 5 people entered the entrance from Outside
# 22 people entered the Cercanias from Outside
# ************************************************
# 101 people stayed in Metro
# 56 people left Metro to Cercanias
# 56 people entered the Cercanias from Metro
# 67 people left Metro to Entrance
# 67 people entered the entrance from Metro
# 3 people stayed in Entrance
# 78 people left entrance to Metro
# 78 people entered the Metro from Entrance
# 19 people left entrance to Cercanias
# 19 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 50 people left Cercanias to Metro
# 50 people entered the Metro from Cercanias
# 33 people left Cercanias to Entrance
# 33 people entered the entrance from Cercanias
# ************************************************
# 14 people left Metro to Outside
# 7 people left entrance to Outside
# 7 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 217 in Metro
# currently 71 in Cercanias
# currently 97 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 6 ==========
#
# ************************************************
# 22 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 107 people stayed in Metro
# 59 people left Metro to Cercanias
# 59 people entered the Cercanias from Metro
# 71 people left Metro to Entrance
# 71 people entered the entrance from Metro
# 3 people stayed in Entrance
# 86 people left entrance to Metro
# 86 people entered the Metro from Entrance
# 21 people left entrance to Cercanias
# 21 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 53 people left Cercanias to Metro
# 53 people entered the Metro from Cercanias
# 35 people left Cercanias to Entrance
# 35 people entered the entrance from Cercanias
# ************************************************
# 9 people left Metro to Outside
# 4 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 239 in Metro
# currently 69 in Cercanias
# currently 106 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 7 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 7 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 112 people stayed in Metro
# 62 people left Metro to Cercanias
# 62 people entered the Cercanias from Metro
# 75 people left Metro to Entrance
# 75 people entered the entrance from Metro
# 3 people stayed in Entrance
# 87 people left entrance to Metro
# 87 people entered the Metro from Entrance
# 21 people left entrance to Cercanias
# 21 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 49 people left Cercanias to Metro
# 49 people entered the Metro from Cercanias
# 33 people left Cercanias to Entrance
# 33 people entered the entrance from Cercanias
# ************************************************
# 13 people left Metro to Outside
# 9 people left entrance to Outside
# 10 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 237 in Metro
# currently 76 in Cercanias
# currently 104 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 8 ==========
#
# ************************************************
# 11 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 111 people stayed in Metro
# 62 people left Metro to Cercanias
# 62 people entered the Cercanias from Metro
# 74 people left Metro to Entrance
# 74 people entered the entrance from Metro
# 3 people stayed in Entrance
# 86 people left entrance to Metro
# 86 people entered the Metro from Entrance
# 21 people left entrance to Cercanias
# 21 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 54 people left Cercanias to Metro
# 54 people entered the Metro from Cercanias
# 36 people left Cercanias to Entrance
# 36 people entered the entrance from Cercanias
# ************************************************
# 7 people left Metro to Outside
# 4 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 245 in Metro
# currently 73 in Cercanias
# currently 111 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 9 ==========
#
# ************************************************
# 27 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 122 people stayed in Metro
# 68 people left Metro to Cercanias
# 68 people entered the Cercanias from Metro
# 81 people left Metro to Entrance
# 81 people entered the entrance from Metro
# 3 people stayed in Entrance
# 96 people left entrance to Metro
# 96 people entered the Metro from Entrance
# 24 people left entrance to Cercanias
# 24 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 51 people left Cercanias to Metro
# 51 people entered the Metro from Cercanias
# 34 people left Cercanias to Entrance
# 34 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 7 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 253 in Metro
# currently 82 in Cercanias
# currently 112 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 10 ==========
#
# ************************************************
# 25 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 19 people entered the Cercanias from Outside
# ************************************************
# 125 people stayed in Metro
# 69 people left Metro to Cercanias
# 69 people entered the Cercanias from Metro
# 83 people left Metro to Entrance
# 83 people entered the entrance from Metro
# 3 people stayed in Entrance
# 93 people left entrance to Metro
# 93 people entered the Metro from Entrance
# 23 people left entrance to Cercanias
# 23 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 59 people left Cercanias to Metro
# 59 people entered the Metro from Cercanias
# 39 people left Cercanias to Entrance
# 39 people entered the entrance from Cercanias
# ************************************************
# 11 people left Metro to Outside
# 11 people left entrance to Outside
# 15 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 267 in Metro
# currently 80 in Cercanias
# currently 115 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 11 ==========
#
# ************************************************
# 16 people entered the Metro from Outside
# 11 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 127 people stayed in Metro
# 70 people left Metro to Cercanias
# 70 people entered the Cercanias from Metro
# 84 people left Metro to Entrance
# 84 people entered the entrance from Metro
# 3 people stayed in Entrance
# 97 people left entrance to Metro
# 97 people entered the Metro from Entrance
# 24 people left entrance to Cercanias
# 24 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 55 people left Cercanias to Metro
# 55 people entered the Metro from Cercanias
# 36 people left Cercanias to Entrance
# 36 people entered the entrance from Cercanias
# ************************************************
# 14 people left Metro to Outside
# 7 people left entrance to Outside
# 6 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 267 in Metro
# currently 91 in Cercanias
# currently 118 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 12 ==========
#
# ************************************************
# 11 people entered the Metro from Outside
# 6 people entered the entrance from Outside
# 21 people entered the Cercanias from Outside
# ************************************************
# 125 people stayed in Metro
# 69 people left Metro to Cercanias
# 69 people entered the Cercanias from Metro
# 83 people left Metro to Entrance
# 83 people entered the entrance from Metro
# 3 people stayed in Entrance
# 96 people left entrance to Metro
# 96 people entered the Metro from Entrance
# 24 people left entrance to Cercanias
# 24 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 65 people left Cercanias to Metro
# 65 people entered the Metro from Cercanias
# 43 people left Cercanias to Entrance
# 43 people entered the entrance from Cercanias
# ************************************************
# 13 people left Metro to Outside
# 4 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 274 in Metro
# currently 83 in Cercanias
# currently 126 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 13 ==========
#
# ************************************************
# 21 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 132 people stayed in Metro
# 73 people left Metro to Cercanias
# 73 people entered the Cercanias from Metro
# 88 people left Metro to Entrance
# 88 people entered the entrance from Metro
# 4 people stayed in Entrance
# 107 people left entrance to Metro
# 107 people entered the Metro from Entrance
# 26 people left entrance to Cercanias
# 26 people entered the Cercanias from Entrance
# 1 people stayed in Cercanias
# 55 people left Cercanias to Metro
# 55 people entered the Metro from Cercanias
# 37 people left Cercanias to Entrance
# 37 people entered the entrance from Cercanias
# ************************************************
# 14 people left Metro to Outside
# 9 people left entrance to Outside
# 7 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 282 in Metro
# currently 95 in Cercanias
# currently 122 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 14 ==========
#
# ************************************************
# 18 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 135 people stayed in Metro
# 75 people left Metro to Cercanias
# 75 people entered the Cercanias from Metro
# 90 people left Metro to Entrance
# 90 people entered the entrance from Metro
# 4 people stayed in Entrance
# 104 people left entrance to Metro
# 104 people entered the Metro from Entrance
# 26 people left entrance to Cercanias
# 26 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 67 people left Cercanias to Metro
# 67 people entered the Metro from Cercanias
# 45 people left Cercanias to Entrance
# 45 people entered the entrance from Cercanias
# ************************************************
# 6 people left Metro to Outside
# 4 people left entrance to Outside
# 7 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 300 in Metro
# currently 97 in Cercanias
# currently 136 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 15 ==========
#
# ************************************************
# 15 people entered the Metro from Outside
# 15 people entered the entrance from Outside
# 18 people entered the Cercanias from Outside
# ************************************************
# 141 people stayed in Metro
# 78 people left Metro to Cercanias
# 78 people entered the Cercanias from Metro
# 94 people left Metro to Entrance
# 94 people entered the entrance from Metro
# 4 people stayed in Entrance
# 117 people left entrance to Metro
# 117 people entered the Metro from Entrance
# 29 people left entrance to Cercanias
# 29 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 67 people left Cercanias to Metro
# 67 people entered the Metro from Cercanias
# 45 people left Cercanias to Entrance
# 45 people entered the entrance from Cercanias
# ************************************************
# 7 people left Metro to Outside
# 4 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 320 in Metro
# currently 105 in Cercanias
# currently 140 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 16 ==========
#
# ************************************************
# 27 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 156 people stayed in Metro
# 86 people left Metro to Cercanias
# 86 people entered the Cercanias from Metro
# 104 people left Metro to Entrance
# 104 people entered the entrance from Metro
# 4 people stayed in Entrance
# 114 people left entrance to Metro
# 114 people entered the Metro from Entrance
# 28 people left entrance to Cercanias
# 28 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 69 people left Cercanias to Metro
# 69 people entered the Metro from Cercanias
# 46 people left Cercanias to Entrance
# 46 people entered the entrance from Cercanias
# ************************************************
# 9 people left Metro to Outside
# 9 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 331 in Metro
# currently 113 in Cercanias
# currently 147 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 17 ==========
#
# ************************************************
# 10 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 8 people entered the Cercanias from Outside
# ************************************************
# 153 people stayed in Metro
# 85 people left Metro to Cercanias
# 85 people entered the Cercanias from Metro
# 102 people left Metro to Entrance
# 102 people entered the entrance from Metro
# 4 people stayed in Entrance
# 123 people left entrance to Metro
# 123 people entered the Metro from Entrance
# 30 people left entrance to Cercanias
# 30 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 71 people left Cercanias to Metro
# 71 people entered the Metro from Cercanias
# 47 people left Cercanias to Entrance
# 47 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 9 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 331 in Metro
# currently 107 in Cercanias
# currently 146 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 18 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 14 people entered the Cercanias from Outside
# ************************************************
# 154 people stayed in Metro
# 85 people left Metro to Cercanias
# 85 people entered the Cercanias from Metro
# 102 people left Metro to Entrance
# 102 people entered the entrance from Metro
# 4 people stayed in Entrance
# 124 people left entrance to Metro
# 124 people entered the Metro from Entrance
# 31 people left entrance to Cercanias
# 31 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 71 people left Cercanias to Metro
# 71 people entered the Metro from Cercanias
# 47 people left Cercanias to Entrance
# 47 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 7 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 334 in Metro
# currently 108 in Cercanias
# currently 147 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 19 ==========
#
# ************************************************
# 18 people entered the Metro from Outside
# 5 people entered the entrance from Outside
# 9 people entered the Cercanias from Outside
# ************************************************
# 158 people stayed in Metro
# 88 people left Metro to Cercanias
# 88 people entered the Cercanias from Metro
# 105 people left Metro to Entrance
# 105 people entered the entrance from Metro
# 4 people stayed in Entrance
# 117 people left entrance to Metro
# 117 people entered the Metro from Entrance
# 29 people left entrance to Cercanias
# 29 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 68 people left Cercanias to Metro
# 68 people entered the Metro from Cercanias
# 45 people left Cercanias to Entrance
# 45 people entered the entrance from Cercanias
# ************************************************
# 15 people left Metro to Outside
# 11 people left entrance to Outside
# 10 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 329 in Metro
# currently 111 in Cercanias
# currently 145 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 20 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 153 people stayed in Metro
# 85 people left Metro to Cercanias
# 85 people entered the Cercanias from Metro
# 102 people left Metro to Entrance
# 102 people entered the entrance from Metro
# 4 people stayed in Entrance
# 123 people left entrance to Metro
# 123 people entered the Metro from Entrance
# 30 people left entrance to Cercanias
# 30 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 72 people left Cercanias to Metro
# 72 people entered the Metro from Cercanias
# 48 people left Cercanias to Entrance
# 48 people entered the entrance from Cercanias
# ************************************************
# 10 people left Metro to Outside
# 12 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 339 in Metro
# currently 104 in Cercanias
# currently 144 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 21 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 7 people entered the entrance from Outside
# 11 people entered the Cercanias from Outside
# ************************************************
# 157 people stayed in Metro
# 87 people left Metro to Cercanias
# 87 people entered the Cercanias from Metro
# 105 people left Metro to Entrance
# 105 people entered the entrance from Metro
# 4 people stayed in Entrance
# 117 people left entrance to Metro
# 117 people entered the Metro from Entrance
# 29 people left entrance to Cercanias
# 29 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 67 people left Cercanias to Metro
# 67 people entered the Metro from Cercanias
# 45 people left Cercanias to Entrance
# 45 people entered the entrance from Cercanias
# ************************************************
# 12 people left Metro to Outside
# 7 people left entrance to Outside
# 10 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 331 in Metro
# currently 109 in Cercanias
# currently 148 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 22 ==========
#
# ************************************************
# 25 people entered the Metro from Outside
# 9 people entered the entrance from Outside
# 18 people entered the Cercanias from Outside
# ************************************************
# 160 people stayed in Metro
# 89 people left Metro to Cercanias
# 89 people entered the Cercanias from Metro
# 106 people left Metro to Entrance
# 106 people entered the entrance from Metro
# 4 people stayed in Entrance
# 121 people left entrance to Metro
# 121 people entered the Metro from Entrance
# 30 people left entrance to Cercanias
# 30 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 74 people left Cercanias to Metro
# 74 people entered the Metro from Cercanias
# 49 people left Cercanias to Entrance
# 49 people entered the entrance from Cercanias
# ************************************************
# 12 people left Metro to Outside
# 5 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 344 in Metro
# currently 112 in Cercanias
# currently 156 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 23 ==========
#
# ************************************************
# 28 people entered the Metro from Outside
# 10 people entered the entrance from Outside
# 11 people entered the Cercanias from Outside
# ************************************************
# 167 people stayed in Metro
# 93 people left Metro to Cercanias
# 93 people entered the Cercanias from Metro
# 111 people left Metro to Entrance
# 111 people entered the entrance from Metro
# 4 people stayed in Entrance
# 128 people left entrance to Metro
# 128 people entered the Metro from Entrance
# 32 people left entrance to Cercanias
# 32 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 72 people left Cercanias to Metro
# 72 people entered the Metro from Cercanias
# 48 people left Cercanias to Entrance
# 48 people entered the entrance from Cercanias
# ************************************************
# 9 people left Metro to Outside
# 9 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 359 in Metro
# currently 117 in Cercanias
# currently 156 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 24 ==========
#
# ************************************************
# 16 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 168 people stayed in Metro
# 93 people left Metro to Cercanias
# 93 people entered the Cercanias from Metro
# 112 people left Metro to Entrance
# 112 people entered the entrance from Metro
# 5 people stayed in Entrance
# 131 people left entrance to Metro
# 131 people entered the Metro from Entrance
# 32 people left entrance to Cercanias
# 32 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 80 people left Cercanias to Metro
# 80 people entered the Metro from Cercanias
# 53 people left Cercanias to Entrance
# 53 people entered the entrance from Cercanias
# ************************************************
# 8 people left Metro to Outside
# 8 people left entrance to Outside
# 7 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 373 in Metro
# currently 122 in Cercanias
# currently 164 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 25 ==========
#
# ************************************************
# 30 people entered the Metro from Outside
# 6 people entered the entrance from Outside
# 13 people entered the Cercanias from Outside
# ************************************************
# 181 people stayed in Metro
# 100 people left Metro to Cercanias
# 100 people entered the Cercanias from Metro
# 120 people left Metro to Entrance
# 120 people entered the entrance from Metro
# 5 people stayed in Entrance
# 131 people left entrance to Metro
# 131 people entered the Metro from Entrance
# 32 people left entrance to Cercanias
# 32 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 79 people left Cercanias to Metro
# 79 people entered the Metro from Cercanias
# 52 people left Cercanias to Entrance
# 52 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 7 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 376 in Metro
# currently 122 in Cercanias
# currently 172 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 26 ==========
#
# ************************************************
# 23 people entered the Metro from Outside
# 10 people entered the entrance from Outside
# 11 people entered the Cercanias from Outside
# ************************************************
# 179 people stayed in Metro
# 99 people left Metro to Cercanias
# 99 people entered the Cercanias from Metro
# 119 people left Metro to Entrance
# 119 people entered the entrance from Metro
# 5 people stayed in Entrance
# 141 people left entrance to Metro
# 141 people entered the Metro from Entrance
# 35 people left entrance to Cercanias
# 35 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 78 people left Cercanias to Metro
# 78 people entered the Metro from Cercanias
# 52 people left Cercanias to Entrance
# 52 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 7 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 383 in Metro
# currently 128 in Cercanias
# currently 170 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 27 ==========
#
# ************************************************
# 21 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 8 people entered the Cercanias from Outside
# ************************************************
# 181 people stayed in Metro
# 101 people left Metro to Cercanias
# 101 people entered the Cercanias from Metro
# 121 people left Metro to Entrance
# 121 people entered the entrance from Metro
# 5 people stayed in Entrance
# 142 people left entrance to Metro
# 142 people entered the Metro from Entrance
# 35 people left entrance to Cercanias
# 35 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 79 people left Cercanias to Metro
# 79 people entered the Metro from Cercanias
# 53 people left Cercanias to Entrance
# 53 people entered the entrance from Cercanias
# ************************************************
# 6 people left Metro to Outside
# 6 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 397 in Metro
# currently 135 in Cercanias
# currently 175 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 28 ==========
#
# ************************************************
# 29 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 191 people stayed in Metro
# 106 people left Metro to Cercanias
# 106 people entered the Cercanias from Metro
# 127 people left Metro to Entrance
# 127 people entered the entrance from Metro
# 5 people stayed in Entrance
# 145 people left entrance to Metro
# 145 people entered the Metro from Entrance
# 36 people left entrance to Cercanias
# 36 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 86 people left Cercanias to Metro
# 86 people entered the Metro from Cercanias
# 57 people left Cercanias to Entrance
# 57 people entered the entrance from Cercanias
# ************************************************
# 11 people left Metro to Outside
# 7 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 413 in Metro
# currently 137 in Cercanias
# currently 183 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 29 ==========
#
# ************************************************
# 22 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 195 people stayed in Metro
# 108 people left Metro to Cercanias
# 108 people entered the Cercanias from Metro
# 130 people left Metro to Entrance
# 130 people entered the entrance from Metro
# 5 people stayed in Entrance
# 152 people left entrance to Metro
# 152 people entered the Metro from Entrance
# 38 people left entrance to Cercanias
# 38 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 89 people left Cercanias to Metro
# 89 people entered the Metro from Cercanias
# 59 people left Cercanias to Entrance
# 59 people entered the entrance from Cercanias
# ************************************************
# 18 people left Metro to Outside
# 7 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 420 in Metro
# currently 139 in Cercanias
# currently 189 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 30 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 9 people entered the Cercanias from Outside
# ************************************************
# 194 people stayed in Metro
# 108 people left Metro to Cercanias
# 108 people entered the Cercanias from Metro
# 129 people left Metro to Entrance
# 129 people entered the entrance from Metro
# 6 people stayed in Entrance
# 157 people left entrance to Metro
# 157 people entered the Metro from Entrance
# 39 people left entrance to Cercanias
# 39 people entered the Cercanias from Entrance
# 2 people stayed in Cercanias
# 87 people left Cercanias to Metro
# 87 people entered the Metro from Cercanias
# 58 people left Cercanias to Entrance
# 58 people entered the entrance from Cercanias
# ************************************************
# 6 people left Metro to Outside
# 6 people left entrance to Outside
# 15 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 433 in Metro
# currently 135 in Cercanias
# currently 188 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 31 ==========
#
# ************************************************
# 15 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 19 people entered the Cercanias from Outside
# ************************************************
# 201 people stayed in Metro
# 112 people left Metro to Cercanias
# 112 people entered the Cercanias from Metro
# 134 people left Metro to Entrance
# 134 people entered the entrance from Metro
# 6 people stayed in Entrance
# 155 people left entrance to Metro
# 155 people entered the Metro from Entrance
# 38 people left entrance to Cercanias
# 38 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 90 people left Cercanias to Metro
# 90 people entered the Metro from Cercanias
# 60 people left Cercanias to Entrance
# 60 people entered the entrance from Cercanias
# ************************************************
# 17 people left Metro to Outside
# 6 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 430 in Metro
# currently 149 in Cercanias
# currently 196 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 32 ==========
#
# ************************************************
# 25 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 204 people stayed in Metro
# 113 people left Metro to Cercanias
# 113 people entered the Cercanias from Metro
# 136 people left Metro to Entrance
# 136 people entered the entrance from Metro
# 6 people stayed in Entrance
# 161 people left entrance to Metro
# 161 people entered the Metro from Entrance
# 40 people left entrance to Cercanias
# 40 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 97 people left Cercanias to Metro
# 97 people entered the Metro from Cercanias
# 64 people left Cercanias to Entrance
# 64 people entered the entrance from Cercanias
# ************************************************
# 11 people left Metro to Outside
# 11 people left entrance to Outside
# 7 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 453 in Metro
# currently 150 in Cercanias
# currently 196 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 33 ==========
#
# ************************************************
# 24 people entered the Metro from Outside
# 6 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 214 people stayed in Metro
# 119 people left Metro to Cercanias
# 119 people entered the Cercanias from Metro
# 143 people left Metro to Entrance
# 143 people entered the entrance from Metro
# 6 people stayed in Entrance
# 156 people left entrance to Metro
# 156 people entered the Metro from Entrance
# 39 people left entrance to Cercanias
# 39 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 99 people left Cercanias to Metro
# 99 people entered the Metro from Cercanias
# 66 people left Cercanias to Entrance
# 66 people entered the entrance from Cercanias
# ************************************************
# 8 people left Metro to Outside
# 12 people left entrance to Outside
# 6 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 462 in Metro
# currently 157 in Cercanias
# currently 204 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 34 ==========
#
# ************************************************
# 21 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 22 people entered the Cercanias from Outside
# ************************************************
# 217 people stayed in Metro
# 120 people left Metro to Cercanias
# 120 people entered the Cercanias from Metro
# 144 people left Metro to Entrance
# 144 people entered the entrance from Metro
# 6 people stayed in Entrance
# 167 people left entrance to Metro
# 167 people entered the Metro from Entrance
# 41 people left entrance to Cercanias
# 41 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 105 people left Cercanias to Metro
# 105 people entered the Metro from Cercanias
# 70 people left Cercanias to Entrance
# 70 people entered the entrance from Cercanias
# ************************************************
# 16 people left Metro to Outside
# 10 people left entrance to Outside
# 5 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 475 in Metro
# currently 160 in Cercanias
# currently 212 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 35 ==========
#
# ************************************************
# 20 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 11 people entered the Cercanias from Outside
# ************************************************
# 222 people stayed in Metro
# 123 people left Metro to Cercanias
# 123 people entered the Cercanias from Metro
# 148 people left Metro to Entrance
# 148 people entered the entrance from Metro
# 6 people stayed in Entrance
# 173 people left entrance to Metro
# 173 people entered the Metro from Entrance
# 43 people left entrance to Cercanias
# 43 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 100 people left Cercanias to Metro
# 100 people entered the Metro from Cercanias
# 67 people left Cercanias to Entrance
# 67 people entered the entrance from Cercanias
# ************************************************
# 6 people left Metro to Outside
# 5 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 491 in Metro
# currently 161 in Cercanias
# currently 218 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 36 ==========
#
# ************************************************
# 12 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 7 people entered the Cercanias from Outside
# ************************************************
# 226 people stayed in Metro
# 125 people left Metro to Cercanias
# 125 people entered the Cercanias from Metro
# 150 people left Metro to Entrance
# 150 people entered the entrance from Metro
# 6 people stayed in Entrance
# 175 people left entrance to Metro
# 175 people entered the Metro from Entrance
# 43 people left entrance to Cercanias
# 43 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 98 people left Cercanias to Metro
# 98 people entered the Metro from Cercanias
# 65 people left Cercanias to Entrance
# 65 people entered the entrance from Cercanias
# ************************************************
# 8 people left Metro to Outside
# 5 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 493 in Metro
# currently 161 in Cercanias
# currently 218 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 37 ==========
#
# ************************************************
# 11 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 226 people stayed in Metro
# 126 people left Metro to Cercanias
# 126 people entered the Cercanias from Metro
# 151 people left Metro to Entrance
# 151 people entered the entrance from Metro
# 6 people stayed in Entrance
# 180 people left entrance to Metro
# 180 people entered the Metro from Entrance
# 45 people left entrance to Cercanias
# 45 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 104 people left Cercanias to Metro
# 104 people entered the Metro from Cercanias
# 69 people left Cercanias to Entrance
# 69 people entered the entrance from Cercanias
# ************************************************
# 12 people left Metro to Outside
# 5 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 499 in Metro
# currently 163 in Cercanias
# currently 222 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 38 ==========
#
# ************************************************
# 26 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 13 people entered the Cercanias from Outside
# ************************************************
# 236 people stayed in Metro
# 131 people left Metro to Cercanias
# 131 people entered the Cercanias from Metro
# 157 people left Metro to Entrance
# 157 people entered the entrance from Metro
# 6 people stayed in Entrance
# 178 people left entrance to Metro
# 178 people entered the Metro from Entrance
# 44 people left entrance to Cercanias
# 44 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 103 people left Cercanias to Metro
# 103 people entered the Metro from Cercanias
# 68 people left Cercanias to Entrance
# 68 people entered the entrance from Cercanias
# ************************************************
# 12 people left Metro to Outside
# 4 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 506 in Metro
# currently 169 in Cercanias
# currently 229 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 39 ==========
#
# ************************************************
# 17 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 9 people entered the Cercanias from Outside
# ************************************************
# 235 people stayed in Metro
# 130 people left Metro to Cercanias
# 130 people entered the Cercanias from Metro
# 156 people left Metro to Entrance
# 156 people entered the entrance from Metro
# 7 people stayed in Entrance
# 183 people left entrance to Metro
# 183 people entered the Metro from Entrance
# 45 people left entrance to Cercanias
# 45 people entered the Cercanias from Entrance
# 3 people stayed in Cercanias
# 104 people left Cercanias to Metro
# 104 people entered the Metro from Cercanias
# 69 people left Cercanias to Entrance
# 69 people entered the entrance from Cercanias
# ************************************************
# 16 people left Metro to Outside
# 4 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 508 in Metro
# currently 168 in Cercanias
# currently 230 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 40 ==========
#
# ************************************************
# 25 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 13 people entered the Cercanias from Outside
# ...
# ************************************************
# 6 people left Metro to Outside
# 11 people left entrance to Outside
# 13 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 885 in Metro
# currently 293 in Cercanias
# currently 388 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 87 ==========
#
# ************************************************
# 10 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 402 people stayed in Metro
# 223 people left Metro to Cercanias
# 223 people entered the Cercanias from Metro
# 268 people left Metro to Entrance
# 268 people entered the entrance from Metro
# 12 people stayed in Entrance
# 311 people left entrance to Metro
# 311 people entered the Metro from Entrance
# 77 people left entrance to Cercanias
# 77 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 179 people left Cercanias to Metro
# 179 people entered the Metro from Cercanias
# 119 people left Cercanias to Entrance
# 119 people entered the entrance from Cercanias
# ************************************************
# 7 people left Metro to Outside
# 12 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 887 in Metro
# currently 295 in Cercanias
# currently 389 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 88 ==========
#
# ************************************************
# 17 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 406 people stayed in Metro
# 226 people left Metro to Cercanias
# 226 people entered the Cercanias from Metro
# 271 people left Metro to Entrance
# 271 people entered the entrance from Metro
# 12 people stayed in Entrance
# 311 people left entrance to Metro
# 311 people entered the Metro from Entrance
# 77 people left entrance to Cercanias
# 77 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 185 people left Cercanias to Metro
# 185 people entered the Metro from Cercanias
# 123 people left Cercanias to Entrance
# 123 people entered the entrance from Cercanias
# ************************************************
# 11 people left Metro to Outside
# 12 people left entrance to Outside
# 14 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 892 in Metro
# currently 296 in Cercanias
# currently 396 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 89 ==========
#
# ************************************************
# 22 people entered the Metro from Outside
# 11 people entered the entrance from Outside
# 18 people entered the Cercanias from Outside
# ************************************************
# 411 people stayed in Metro
# 228 people left Metro to Cercanias
# 228 people entered the Cercanias from Metro
# 274 people left Metro to Entrance
# 274 people entered the entrance from Metro
# 12 people stayed in Entrance
# 315 people left entrance to Metro
# 315 people entered the Metro from Entrance
# 78 people left entrance to Cercanias
# 78 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 184 people left Cercanias to Metro
# 184 people entered the Metro from Cercanias
# 123 people left Cercanias to Entrance
# 123 people entered the entrance from Cercanias
# ************************************************
# 10 people left Metro to Outside
# 11 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 901 in Metro
# currently 304 in Cercanias
# currently 400 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 90 ==========
#
# ************************************************
# 20 people entered the Metro from Outside
# 12 people entered the entrance from Outside
# 9 people entered the Cercanias from Outside
# ************************************************
# 414 people stayed in Metro
# 230 people left Metro to Cercanias
# 230 people entered the Cercanias from Metro
# 276 people left Metro to Entrance
# 276 people entered the entrance from Metro
# 12 people stayed in Entrance
# 319 people left entrance to Metro
# 319 people entered the Metro from Entrance
# 79 people left entrance to Cercanias
# 79 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 184 people left Cercanias to Metro
# 184 people entered the Metro from Cercanias
# 122 people left Cercanias to Entrance
# 122 people entered the entrance from Cercanias
# ************************************************
# 6 people left Metro to Outside
# 5 people left entrance to Outside
# 15 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 912 in Metro
# currently 301 in Cercanias
# currently 407 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 91 ==========
#
# ************************************************
# 24 people entered the Metro from Outside
# 5 people entered the entrance from Outside
# 15 people entered the Cercanias from Outside
# ************************************************
# 421 people stayed in Metro
# 234 people left Metro to Cercanias
# 234 people entered the Cercanias from Metro
# 280 people left Metro to Entrance
# 280 people entered the entrance from Metro
# 12 people stayed in Entrance
# 319 people left entrance to Metro
# 319 people entered the Metro from Entrance
# 79 people left entrance to Cercanias
# 79 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 185 people left Cercanias to Metro
# 185 people entered the Metro from Cercanias
# 123 people left Cercanias to Entrance
# 123 people entered the entrance from Cercanias
# ************************************************
# 16 people left Metro to Outside
# 4 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 910 in Metro
# currently 309 in Cercanias
# currently 413 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 92 ==========
#
# ************************************************
# 13 people entered the Metro from Outside
# 14 people entered the entrance from Outside
# 17 people entered the Cercanias from Outside
# ************************************************
# 415 people stayed in Metro
# 230 people left Metro to Cercanias
# 230 people entered the Cercanias from Metro
# 276 people left Metro to Entrance
# 276 people entered the entrance from Metro
# 12 people stayed in Entrance
# 331 people left entrance to Metro
# 331 people entered the Metro from Entrance
# 82 people left entrance to Cercanias
# 82 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 191 people left Cercanias to Metro
# 191 people entered the Metro from Cercanias
# 127 people left Cercanias to Entrance
# 127 people entered the entrance from Cercanias
# ************************************************
# 8 people left Metro to Outside
# 4 people left entrance to Outside
# 11 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 931 in Metro
# currently 309 in Cercanias
# currently 413 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 93 ==========
#
# ************************************************
# 14 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 20 people entered the Cercanias from Outside
# ************************************************
# 425 people stayed in Metro
# 236 people left Metro to Cercanias
# 236 people entered the Cercanias from Metro
# 283 people left Metro to Entrance
# 283 people entered the entrance from Metro
# 12 people stayed in Entrance
# 326 people left entrance to Metro
# 326 people entered the Metro from Entrance
# 81 people left entrance to Cercanias
# 81 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 193 people left Cercanias to Metro
# 193 people entered the Metro from Cercanias
# 128 people left Cercanias to Entrance
# 128 people entered the entrance from Cercanias
# ************************************************
# 16 people left Metro to Outside
# 6 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 929 in Metro
# currently 316 in Cercanias
# currently 419 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 94 ==========
#
# ************************************************
# 22 people entered the Metro from Outside
# 15 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 427 people stayed in Metro
# 237 people left Metro to Cercanias
# 237 people entered the Cercanias from Metro
# 285 people left Metro to Entrance
# 285 people entered the entrance from Metro
# 13 people stayed in Entrance
# 336 people left entrance to Metro
# 336 people entered the Metro from Entrance
# 84 people left entrance to Cercanias
# 84 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 192 people left Cercanias to Metro
# 192 people entered the Metro from Cercanias
# 128 people left Cercanias to Entrance
# 128 people entered the entrance from Cercanias
# ************************************************
# 18 people left Metro to Outside
# 12 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 939 in Metro
# currently 317 in Cercanias
# currently 415 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 95 ==========
#
# ************************************************
# 19 people entered the Metro from Outside
# 13 people entered the entrance from Outside
# 9 people entered the Cercanias from Outside
# ************************************************
# 431 people stayed in Metro
# 239 people left Metro to Cercanias
# 239 people entered the Cercanias from Metro
# 287 people left Metro to Entrance
# 287 people entered the entrance from Metro
# 12 people stayed in Entrance
# 332 people left entrance to Metro
# 332 people entered the Metro from Entrance
# 83 people left entrance to Cercanias
# 83 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 191 people left Cercanias to Metro
# 191 people entered the Metro from Cercanias
# 127 people left Cercanias to Entrance
# 127 people entered the entrance from Cercanias
# ************************************************
# 15 people left Metro to Outside
# 6 people left entrance to Outside
# 9 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 940 in Metro
# currently 321 in Cercanias
# currently 421 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 96 ==========
#
# ************************************************
# 13 people entered the Metro from Outside
# 10 people entered the entrance from Outside
# 12 people entered the Cercanias from Outside
# ************************************************
# 428 people stayed in Metro
# 238 people left Metro to Cercanias
# 238 people entered the Cercanias from Metro
# 285 people left Metro to Entrance
# 285 people entered the entrance from Metro
# 12 people stayed in Entrance
# 334 people left entrance to Metro
# 334 people entered the Metro from Entrance
# 83 people left entrance to Cercanias
# 83 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 195 people left Cercanias to Metro
# 195 people entered the Metro from Cercanias
# 130 people left Cercanias to Entrance
# 130 people entered the entrance from Cercanias
# ************************************************
# 16 people left Metro to Outside
# 5 people left entrance to Outside
# 13 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 943 in Metro
# currently 316 in Cercanias
# currently 424 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 97 ==========
#
# ************************************************
# 13 people entered the Metro from Outside
# 10 people entered the entrance from Outside
# 7 people entered the Cercanias from Outside
# ************************************************
# 430 people stayed in Metro
# 239 people left Metro to Cercanias
# 239 people entered the Cercanias from Metro
# 286 people left Metro to Entrance
# 286 people entered the entrance from Metro
# 13 people stayed in Entrance
# 336 people left entrance to Metro
# 336 people entered the Metro from Entrance
# 84 people left entrance to Cercanias
# 84 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 189 people left Cercanias to Metro
# 189 people entered the Metro from Cercanias
# 126 people left Cercanias to Entrance
# 126 people entered the entrance from Cercanias
# ************************************************
# 12 people left Metro to Outside
# 12 people left entrance to Outside
# 12 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 944 in Metro
# currently 319 in Cercanias
# currently 414 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 98 ==========
#
# ************************************************
# 18 people entered the Metro from Outside
# 5 people entered the entrance from Outside
# 15 people entered the Cercanias from Outside
# ************************************************
# 432 people stayed in Metro
# 240 people left Metro to Cercanias
# 240 people entered the Cercanias from Metro
# 288 people left Metro to Entrance
# 288 people entered the entrance from Metro
# 12 people stayed in Entrance
# 325 people left entrance to Metro
# 325 people entered the Metro from Entrance
# 81 people left entrance to Cercanias
# 81 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 196 people left Cercanias to Metro
# 196 people entered the Metro from Cercanias
# 130 people left Cercanias to Entrance
# 130 people entered the entrance from Cercanias
# ************************************************
# 14 people left Metro to Outside
# 5 people left entrance to Outside
# 6 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 941 in Metro
# currently 323 in Cercanias
# currently 426 in Entrance
# ===========================================
#
#  ========== Simulation Cycle 99 ==========
#
# ************************************************
# 25 people entered the Metro from Outside
# 8 people entered the entrance from Outside
# 16 people entered the Cercanias from Outside
# ************************************************
# 434 people stayed in Metro
# 241 people left Metro to Cercanias
# 241 people entered the Cercanias from Metro
# 289 people left Metro to Entrance
# 289 people entered the entrance from Metro
# 13 people stayed in Entrance
# 336 people left entrance to Metro
# 336 people entered the Metro from Entrance
# 84 people left entrance to Cercanias
# 84 people entered the Cercanias from Entrance
# 6 people stayed in Cercanias
# 199 people left Cercanias to Metro
# 199 people entered the Metro from Cercanias
# 132 people left Cercanias to Entrance
# 132 people entered the entrance from Cercanias
# ************************************************
# 8 people left Metro to Outside
# 7 people left entrance to Outside
# 6 people left Cercanias to Outside
# ************************************************
# ===========================================
# currently 963 in Metro
# currently 327 in Cercanias
# currently 428 in Entrance
# ===========================================
